# %% [markdown]
# installation :
# https://www.python.org/downloads/
#
# - ajouter Python aux variables d'environnement (cocher **Add python.exe to PATH** lors de l'installation)
# - vérifier que Python est reconnu

# %% [markdown]
# ```bash
# py --version        # affiche la version installée (ex : Python 3.13.1)
# py                  # lance l'interpréteur interactif Python dans le terminal
# >>> print("hello world")
# >>> quit()          # quitte l'interpréteur
# ```

# %%
print('hello')

# %% [markdown]
# Structure d'un fichier
#
# - import
#
# - declarations
#
# - methodes
#
# - code principale

# %% [markdown]
# L'indentation :
#
# doit être respecter dans un "bloc"
#
# une fois que l'on sort du bloc on retourne au niveau précédent

# %%
age = 20

if age > 20:
    print(age)
    print("hello")
    
print("hello")

# %% [markdown]
# Commentaires
#
# - `#` : commentaire sur une ligne
#
# - """ """ ou ''' ''' : commentaire sur plusieurs lignes

# %%
# un commentaire sur une ligne

"""
un commentaire
sur plusieurs 
lignes
"""
