# %% [markdown]
# ecriture et lecture depuis un fichier

# %%
import json

# r lire
# w ecrire
# a ajouter
# with open( "journal.json" , "w" , encoding="utf-8") as fichier:
#     fichier.write("python 2 \n")
    
    
with open("journal.json" , "r" ,encoding="utf-8" ) as fichier:
    for numero , ligne in enumerate(fichier,start=1):
        print(f"{numero} = {ligne}")



# taches = [
#     {"titre":"apprendre python","complete":False},
#     {"titre":"apprendre c#","complete":False},
# ]

# with open("tache.json" , "w" , encoding="utf-8") as fichier:
#     json.dump(taches,fichier, indent=2 , ensure_ascii=False)
    
    
with open("tache.json","r" , encoding="utf-8") as fichier:
    taches_from_file = json.load(fichier)
    
for v in taches_from_file:
    print(v)
